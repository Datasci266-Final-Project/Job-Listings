# %% [markdown]
# <a href="https://colab.research.google.com/github/Datasci266-Final-Project/Job-Listings/blob/main/Analysis%20Notebooks/Language_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install langdetect --quiet
from langdetect import detect

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/DataSci 266 Project
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1V3QooLePiHR_DaZhbXQhsjmP1Ez5fv5F/DataSci 266 Project

# %%
test_data = pd.read_csv('test_data_with_predictions.csv')

# %%
test_data_baseline = pd.read_csv('test_data_with_baseline_predictions.csv')

# %%
len(test_data_baseline)
# Out:
# 14063

# %%
len(test_data)
# Out:
# 14063

# %%
test_data.head()
# Out:
#    index                                              title  \
# 0  17953  Real Estate Fund Accounting Senior Client Mana...
# 1  97031                                 Investment Analyst
# 2  64933            Accounts payable accountant Fr-En (M/F)
# 3  79240  Concepteur d'offres de formation - Division du...
# 4  89706                                         SC Analyst
#
#                                                 text   level   salary  \
# 0  Credit Suisse is a leading global wealth manag...  senior      NaN
# 1  <p><strong><u>INVESTMENT ANALYST in Luxembourg...  junior      NaN
# 2  Job Description LE POSTE : For one of our clie...     NaN  55000.0
# 3  Missions Le concepteur d’offre sera en charge ...   entry      NaN
# 4  Description At Amazon Logistics (AMZL), we str...  junior      NaN
#
#   salary_bucket  level_labels  salary_labels  level_predictions_bert_base  \
# 0           NaN             4             -1                            1
# ...

# %%
combined_test_data = test_data.copy()
combined_test_data['level_predictions_dan'] = test_data_baseline['dan_level_predictions']
combined_test_data['salary_predictions_dan'] = test_data_baseline['dan_salary_predictions']

# %%
combined_test_data.head()
# Out:
#    index                                              title  \
# 0  17953  Real Estate Fund Accounting Senior Client Mana...
# 1  97031                                 Investment Analyst
# 2  64933            Accounts payable accountant Fr-En (M/F)
# 3  79240  Concepteur d'offres de formation - Division du...
# 4  89706                                         SC Analyst
#
#                                                 text   level   salary  \
# 0  Credit Suisse is a leading global wealth manag...  senior      NaN
# 1  <p><strong><u>INVESTMENT ANALYST in Luxembourg...  junior      NaN
# 2  Job Description LE POSTE : For one of our clie...     NaN  55000.0
# 3  Missions Le concepteur d’offre sera en charge ...   entry      NaN
# 4  Description At Amazon Logistics (AMZL), we str...  junior      NaN
#
#   salary_bucket  level_labels  salary_labels  level_predictions_bert_base  \
# 0           NaN             4             -1                            1
# ...

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return None


combined_test_data['language'] = combined_test_data['text'].apply(detect_language)

# %%
language_names = {
    'en': 'English',
    'fr': 'French',
    'de': 'German',
    'nl': 'Dutch',
    'es': 'Spanish',
    'it': 'Italian',
    'pt': 'Portuguese',
    'pl': 'Polish',
    'da': 'Danish',
    'ro': 'Romanian'
}

combined_test_data['language_full_name'] = combined_test_data['language'].map(language_names)

# %%
combined_test_data['language_full_name'].value_counts()
# Out:
# language_full_name
# English    11875
# French      1896
# German       274
# Dutch         14
# Italian        2
# Spanish        1
# Name: count, dtype: int64

# %%
combined_test_data.to_csv(r'test_data_lang_predictions.csv', index = False)

# %%
combined_test_data.head()
# Out:
#    index                                              title  \
# 0  17953  Real Estate Fund Accounting Senior Client Mana...
# 1  97031                                 Investment Analyst
# 2  64933            Accounts payable accountant Fr-En (M/F)
# 3  79240  Concepteur d'offres de formation - Division du...
# 4  89706                                         SC Analyst
#
#                                                 text   level   salary  \
# 0  Credit Suisse is a leading global wealth manag...  senior      NaN
# 1  <p><strong><u>INVESTMENT ANALYST in Luxembourg...  junior      NaN
# 2  Job Description LE POSTE : For one of our clie...     NaN  55000.0
# 3  Missions Le concepteur d’offre sera en charge ...   entry      NaN
# 4  Description At Amazon Logistics (AMZL), we str...  junior      NaN
#
#   salary_bucket  level_labels  salary_labels  level_predictions_bert_base  \
# 0           NaN             4             -1                            1
# ...
